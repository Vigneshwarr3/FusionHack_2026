# %% [markdown]
# # Template notebook
#
# **Question:** What are we trying to answer in this notebook?
#
# **Data:** Which upstream tables/files are used? Where do they live?
#
# **Method:** Which `aquiferwatch.*` functions are called? Any new modeling choices?
#
# **Conclusion:** Filled in after the analysis runs — what did we find, and what's the next action?

# %%
# %load_ext autoreload
# %autoreload 2

import mlflow
import pandas as pd

from aquiferwatch.mlflow_utils import start_run
from aquiferwatch.config import settings

print(f"tracking URI: {settings.mlflow_tracking_uri}")
print(f"team member:  {settings.team_member}")

# %%
# Example: a no-op run to verify MLflow wiring.
with start_run(module="smoke", run_name="template_smoke") as run:
    mlflow.log_params({"note": "replace this notebook with real work"})
    mlflow.log_metrics({"hello": 1.0})
    print(f"Logged run_id = {run.info.run_id}")
